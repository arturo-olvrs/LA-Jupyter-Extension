# %% [markdown]
# # Week 5: Loops Practice Exercises
#
# Complete the following exercises to practice working with while loops and for loops in Python.
#
# **Instructions:**
# - Read each problem carefully
# - Write your code in the provided cells
# - Test your code with the given examples
# - Make sure your output matches the expected format

# %% [markdown]
# ---
# ## Exercise 1: While Loop - Easy (20 points)
#
# **Problem:** Write a program that counts from 15 to 5 using a while loop. Print each number on a separate line.
#
# **Example:**
# ```
# Output:
# 15
# 14
# 13
# 12
# 11
# 10
# 9
# 8
# 7
# 6
# 5
# ```

# %%
# Write your code here

# %% [markdown]
# ---
# ## Exercise 2: While Loop - Medium (25 points)
#
# **Problem:** Write a program that asks the user to enter positive numbers. Keep asking until the user enters -1. After the user enters -1, display:
# - The total sum of all entered numbers (excluding -1)
# - The count of numbers entered (excluding -1)
# - The average of the numbers (excluding -1)
#
# **Example:**
# ```
# Enter a number (-1 to stop): 10
# Enter a number (-1 to stop): 20
# Enter a number (-1 to stop): 30
# Enter a number (-1 to stop): -1
#
# Total sum: 60
# Count: 3
# Average: 20.0
# ```

# %%
# Write your code here

# %% [markdown]
# ---
# ## Exercise 3: For Loop - Medium (25 points)
#
# **Problem:** Write a program that prints a left triangle pattern with 5 rows using a for loop.
#
# **Example:**
# ```
#     *
#    **
#   ***
#  ****
# *****
# ```
#
# **Hint:** You may need to use nested loops or string multiplication.

# %%
# Write your code here

# %% [markdown]
# ---
# ## Exercise 4: For Loop - Hard (30 points)
#
# **Problem:** Write a program that finds all multiple of 7 numbers between 1 and 50 (inclusive). SThen:
# 1. Print the multiple of 7 numbers
# 2. Print the count of multiple of 7 numbers found
# 3. Print the sum of all multiple of 7 numbers
#
# **Definition:** A number is a multiple of 7 if it is divisible by 7 (remainder is 0 when divided by 7)
#
# **Example:**
# ```
# multiple of 7 numbers: [7, 14, 21, 28, 35, 42, 49]
# Count: 7
# Sum: 196
# ```

# %%
# Write your code here

# %% [markdown]
# ---
# ## Submission
#
# Make sure all your code runs without errors before submitting. Test each exercise thoroughly!
#
# **Total Time Spent:** _____ hours
#
# **Difficulty Rating:** (Keep one, erase the others)
# Too Easy | Just Right | Too Hard
#
# **Comments or Questions:**

# %% [markdown]
# ## Self-Reflection
# **How do you estimate your programming experience with other people from your exercise group?** <br>
# 1 - Clearly Worse
# 2 - Worse
# 3 - Identical
# 4 - Better
# 5 - Clearly better <br>
#
# Please just indicate the number in the cell below.

# %%
#add response here
