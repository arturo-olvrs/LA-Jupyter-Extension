# %% [markdown]
# # Welcome to Your Python Exercise!
#
# **Introduction:**
#
# In this exercise, you will work on **eight Python programming tasks**. While programming, you will have a **Dashboard** opened that will mainly provide information about your errors and successful executions.
#
# If the Dashboard is closed, you can reopen it by navigating to:
# ```
# View -> Activate Command Palette -> Open Notebook Dashboard
# ```
#
# The tasks are arranged in **increasing order of difficulty**, but you may solve them in **any order**; it is not required to complete them sequentially.
#
# ## Important Instructions
#
# Please **do not modify the notebook structure** in any way. This means:
#
# - **Do not add new cells**
# - **Do not delete existing cells**
# - **Do not change the order of the cells**
#
# You should only **fill in the code cells** provided for the exercises. All other modifications may cause the dashboard to malfunction.
#
# After finishing all the exercises, you will be asked to complete a **short survey**. The link to this survey will be provided at the end of the notebook.
#
# Good luck and happy coding!

# %% [markdown]
# ---
# ## While and For Loops Practice Exercises

# %% [markdown]
# ### Exercise 1: While Loop
#
# **Problem:** Write a program that counts from 15 to 5 using a while loop. Print each number on a separate line.
#
# **Example:**
# ```
# Output:
# 15
# 14
# 13
# 12
# 11
# 10
# 9
# 8
# 7
# 6
# 5
# ```

# %%
# Write your code for exercise 1 here

# %% [markdown]
# ### Exercise 2: While Loop
#
# **Problem:** Write a program that asks the user to enter positive numbers. Keep asking until the user enters -1. After the user enters -1, display:
# - The total sum of all entered numbers (excluding -1)
# - The count of numbers entered (excluding -1)
# - The average of the numbers (excluding -1)
#
# **Example:**
# ```
# Enter a number (-1 to stop): 10
# Enter a number (-1 to stop): 20
# Enter a number (-1 to stop): 30
# Enter a number (-1 to stop): -1
#
# Total sum: 60
# Count: 3
# Average: 20.0
# ```

# %%
# Write your code for exercise 2 here

# %% [markdown]
# ### Exercise 3: For Loop
#
# **Problem:** Write a program that prints a left triangle pattern with 5 rows using a for loop.
#
# **Example:**
# ```
#     *
#    **
#   ***
#  ****
# *****
# ```
#
# **Hint:** You may need to use nested loops or string multiplication.

# %%
# Write your code for exercise 3 here

# %% [markdown]
# ### Exercise 4: For Loop
#
# **Problem:** Write a program that finds all multiple of 7 numbers between 1 and 50 (inclusive). Then:
# 1. Print the multiple of 7 numbers
# 2. Print the count of multiple of 7 numbers found
# 3. Print the sum of all multiple of 7 numbers
#
# **Definition:** A number is a multiple of 7 if it is divisible by 7 (remainder is 0 when divided by 7)
#
# **Example:**
# ```
# multiple of 7 numbers: [7, 14, 21, 28, 35, 42, 49]
# Count: 7
# Sum: 196
# ```

# %%
# Write your code for exercise 4 here

# %% [markdown]
# ---
# ## Data Structures: Lists, Sets, Tuples, and Dictionaries

# %% [markdown]
# ### Exercise 1: Color List String
#
# Given the list with colors, concatenate the list elements to a single string.
#
# **Requirements:**
# - Use a loop to iterate through the list
# - Concatenate all colors into a single string separated by commas and spaces
# - Print the final string

# %%
# Given list
colors = ['Brick', 'Rust', 'Mustard', 'Pine', 'Teal', 'Ink', 'Violet']

# Your code here

# %% [markdown]
# **Expected Output:**
# ```
# Brick, Rust, Mustard, Pine, Teal, Ink, Violet
# ```

# %% [markdown]
# ### Exercise 2: Student Courses Analysis
#
# Create two sets, one for Amelia and one for Benjamin, and store the courses taken by them.
# - Amelia is taking: Chemistry, Biology, Math, English
# - Benjamin is taking: English, Physics, Math, Computer Science
#
# Then perform the following operations:
# 1. Find courses both students are taking
# 2. Find all unique courses being taken by either student
# 3. Find courses only Amelia is taking
# 4. Add 'Psychology' to Amelia's courses and check if 'Chemistry' is in the set
# 5. Print the number of unique courses in total

# %%
# Create sets for Amelia and Benjamin
# Your code here


# 1. Find courses both students are taking
print("Courses both students are taking:")
# Your code here


# 2. Find all unique courses being taken by either student
print("\nAll unique courses:")
# Your code here


# 3. Find courses only Amelia is taking
print("\nCourses only Amelia is taking:")
# Your code here


# 4. Add 'Psychology' to Amelia's courses and check if 'Chemistry' is in the set
print("\nAfter adding Psychology:")
# Your code here


# 5. Print the number of unique courses in total
print("\nTotal number of unique courses:")
# Your code here

# %% [markdown]
# **Expected Output:**
# ```
# Courses both students are taking:
# {'Math', 'English'}
#
# All unique courses:
# {'Biology', 'Physics', 'Computer Science', 'English', 'Math', 'Chemistry'}
#
# Courses only Amelia is taking:
# {'Biology', 'Chemistry'}
#
# After adding Psychology:
# Amelia's courses: {'Biology', 'Math', 'Psychology', 'Chemistry', 'English'}
# Is Chemistry in Amelia's courses? True
#
# Total number of unique courses:
# 7
# ```

# %% [markdown]
# ### Exercise 3: Count Element Occurrences in Tuple
#
# Write a program that counts how many times a specific element appears in a tuple.
#
# **Requirements:**
# - Use a loop to iterate through the tuple
# - Use a counter variable to count occurrences
# - Do NOT use the built-in count() method
# - Print the result

# %%
# Given tuple
numbers = (9, 3, 9, 9, 6, 9, 2, 9, 4)
target = 9

# Your code here

# %% [markdown]
# **Expected Output:**
# ```
# The number 9 appears 5 times in the tuple.
# ```

# %% [markdown]
# ### Exercise 4: Dictionary Key-Value Swap
#
# Given a dictionary with English-German word pairs, write a program that swaps keys and values.
# - The original dictionary is named `anglogerman`
# - Store the swapped dictionary in a variable named `germananglo`
#
# **Requirements:**
# - Create a new dictionary with swapped keys and values
# - Print both dictionaries to compare

# %%
# Given dictionary
anglogerman = {
    "car": "auto",
    "train": "zug",
    "bicycle": "fahrrad",
    "street": "strasse",
    "city": "stadt",
    "country": "land"
}

# Your code here


# Print both dictionaries
print("Original (English to German):")
print(anglogerman)
print("\nSwapped (German to English):")
print(germananglo)

# %% [markdown]
# **Expected Output:**
# ```
# Original (English to German):
# {'car': 'auto', 'train': 'zug', 'bicycle': 'fahrrad', 'street': 'strasse', 'city': 'stadt', 'country': 'land'}
#
# Swapped (German to English):
# {'auto': 'car', 'zug': 'train', 'fahrrad': 'bicycle', 'strasse': 'street', 'stadt': 'city', 'land': 'country'}
# ```

# %% [markdown]
# ---
# ## This is the end of the exercise!
# Before closing the notebook, please click on the link below or scan the QR code and complete our **short survey**. It is really important!
#
# ![QR Code](../style/QR_Survey.jpeg)
#
# [https://limesurvey.uni-due.de/index.php/942317?lang=en](https://limesurvey.uni-due.de/index.php/942317?lang=en)
